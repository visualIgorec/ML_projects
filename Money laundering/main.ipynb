# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# modules
from src.load import LoadData
from src.preprocessing import PrepareData
from src.train import ClassificationModel
from src.eval import Eval

# load data
train_path = 'data/train.csv'
test_path = 'data/test.csv'
train = LoadData.load(train_path)
test = LoadData.load(test_path)

# %%
train.head(3)
# Out:
#    user_id   fact_dt  emb_0000  emb_0001  emb_0002  emb_0003  emb_0004  \
# 0        0  711 days -1.130920  1.895028 -1.736251  0.872448 -0.854317
# 1        1  218 days -1.777758  2.195476 -1.177928  0.997776 -0.966194
# 2        2  462 days -0.800151  2.204143 -0.514011  0.961015 -0.116245
#
#    emb_0005  emb_0006  emb_0007  ...  entity_0009_rt  entity_0010_rt  \
# 0  0.545024  1.202575 -0.072018  ...             NaN        1.000000
# 1  0.702989  0.975820  0.703755  ...        0.975221        0.996865
# 2  0.218591  1.152742  0.955213  ...             NaN        0.781602
#
#    entity_0011_ct  entity_0012_ct  entity_0013_ct  entity_0014_rt  \
# 0               3           446.0             207        1.166190
# 1               3           330.0             200        1.753914
# 2               2           191.0              82        1.548657
#
#    entity_0015_ct  entity_0016_rt  entity_0017_cd  target
# 0             NaN        1.008388               d       1
# ...

# %%
train.info(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106235 entries, 0 to 106234
# Data columns (total 84 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   user_id         106235 non-null  int64
#  1   fact_dt         106235 non-null  object
#  2   emb_0000        106235 non-null  float64
#  3   emb_0001        106235 non-null  float64
#  4   emb_0002        106235 non-null  float64
#  5   emb_0003        106235 non-null  float64
#  6   emb_0004        106235 non-null  float64
#  7   emb_0005        106235 non-null  float64
#  8   emb_0006        106235 non-null  float64
#  9   emb_0007        106235 non-null  float64
#  10  emb_0008        106235 non-null  float64
#  11  emb_0009        106235 non-null  float64
#  12  emb_0010        106235 non-null  float64
#  13  emb_0011        106235 non-null  float64
#  14  emb_0012        106235 non-null  float64
#  15  emb_0013        106235 non-null  float64
# ...

# %%
test.head(3)
# Out:
#    Id  user_id   fact_dt  emb_0000  emb_0001  emb_0002  emb_0003  emb_0004  \
# 0   0   104363  552 days -1.786346  2.074665 -1.504628  1.143300 -0.979666
# 1   1   104364  152 days -1.555227  1.703838 -1.682477  1.143936 -1.363388
# 2   2   104365  714 days -1.350453  1.907620 -1.563653  1.271580 -0.902961
#
#    emb_0005  emb_0006  ...  entity_0008_ct  entity_0009_rt  entity_0010_rt  \
# 0  0.750931  1.091962  ...             NaN             1.0        0.997459
# 1  0.921123  1.209163  ...             NaN             1.0             NaN
# 2  0.582773  1.127565  ...             NaN             1.0        1.000000
#
#    entity_0011_ct  entity_0012_ct  entity_0013_ct  entity_0014_rt  \
# 0               3           339.0             173        2.300125
# 1               1            98.0              54        1.598273
# 2               2           235.0             109        1.368001
#
#    entity_0015_ct  entity_0016_rt  entity_0017_cd
# ...

# %%
test.info(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26824 entries, 0 to 26823
# Data columns (total 84 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id              26824 non-null  int64
#  1   user_id         26824 non-null  int64
#  2   fact_dt         26824 non-null  object
#  3   emb_0000        26824 non-null  float64
#  4   emb_0001        26824 non-null  float64
#  5   emb_0002        26824 non-null  float64
#  6   emb_0003        26824 non-null  float64
#  7   emb_0004        26824 non-null  float64
#  8   emb_0005        26824 non-null  float64
#  9   emb_0006        26824 non-null  float64
#  10  emb_0007        26824 non-null  float64
#  11  emb_0008        26824 non-null  float64
#  12  emb_0009        26824 non-null  float64
#  13  emb_0010        26824 non-null  float64
#  14  emb_0011        26824 non-null  float64
#  15  emb_0012        26824 non-null  float64
#  16  emb_0013        26824 non-null  float64
# ...

# %%
# подготовка данных для обучения и тестирования

modifiedData = PrepareData(train, test, valid_size=0.3, random_number=42, norm=True)
dict_obj = modifiedData.main_process()

x_train = dict_obj['x_train']
x_val = dict_obj['x_val']
x_test = dict_obj['x_test']
y_train = dict_obj['y_train']
y_val = dict_obj['y_val']
id_person_test = dict_obj['id_person_test']

# %%
# Обучение модели 

clf_obj = ClassificationModel(x_train, y_train)
clf_logreg = clf_obj.train()

# %%
Eval._eval(clf_logreg, x_val, y_val, x_test, id_person_test)
# Out:
# roc_auc_score on valid set: 1.0
